# %% [markdown]
# # FAILSAFE — EDA notebook
#
# Mirrors `ml/src/eda.py`. Run cells top-to-bottom; figures land in `ml/reports/`.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
import matplotlib.pyplot as plt
import seaborn as sns
from src.data import load_raw, add_target
from src.config import NUMERIC_FEATURES, TARGET_COL
sns.set_theme(style='whitegrid', context='talk')
df = add_target(load_raw())
print(df.shape, '| at-risk rate =', round(df[TARGET_COL].mean()*100, 2), '%')
df.head()

# %%
fig, ax = plt.subplots(figsize=(7,4))
sns.histplot(df['G3'], bins=21, kde=True, color='#118ab2', ax=ax)
ax.axvline(10, color='crimson', ls='--', label='Pass threshold')
ax.set_title('Final grade distribution')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,8))
corr = df[NUMERIC_FEATURES + ['G3', TARGET_COL]].corr(numeric_only=True)
sns.heatmap(corr, cmap='vlag', center=0, ax=ax, cbar_kws={'shrink':0.8})
ax.set_title('Numeric correlations')
plt.show()

# %%
from src.eda import main as run_eda
run_eda()  # also writes PNGs to ml/reports/
